# %%
from __future__ import division
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import copy
import random

N =  50                 # Number of nodes
rw = 700                 # Wealth value of rich
pw = 300                # Wealth value of poor
we_arr = [rw, pw]       # Array storing both the wealth values
pr = 0.5                # Probability of being rich
prob_arr = [pr, 1-pr]  # Array storing probability of wealth allotment values
M = 20                  # Number of rounds
co = 50                 # Unitary Cost of co-operation
be = 100                # Unitary Benefit of co-operation
re = 0.3                # Rewiring probability
S = 50                  # Number of iterations
pl = 0.3                # Initial probability of a link being formed between any two nodes

def inv_logit(y):
    inv_logit_out =(np.exp(y)/(1+np.exp(y)))
    return inv_logit_out

def gini_calc(x):       #IN: Wealth values across the population, OUT: Gini Coefficient
    sum2=0
    for i in range(len(x)):
        sum1=0
        for j in range(len(x)):
            sum1=sum1+np.abs(x[i]-x[j])
        sum2=sum2+sum1;
    
    gini=sum2/(2*len(x)**2*np.mean(x));
    return gini

node_arr = np.arange(N)
p0_ar = np.arange(0.55,1.05,0.05)

rc_ar = np.zeros([len(p0_ar),S])   # Array for storing no of cooperations by rich individuals
rd_ar = np.zeros([len(p0_ar),S])   # Array for storing no of defections by rich individuals
pd_ar = np.zeros([len(p0_ar),S])   # Array for storing no of defections by poor individuals
pc_ar = np.zeros([len(p0_ar),S])   # Array for storing no of cooperations by poor individuals
c_env_ar = np.zeros([len(p0_ar),S]) # Array storing no of cooperative environments 
d_env_ar = np.zeros([len(p0_ar),S])  # Array storing no of selfish environments 
eq_env_ar = np.zeros([len(p0_ar),S])  # Array storing no of neutral environments 
coop_ar = np.zeros([len(p0_ar),S])    # Array storing no of cooperators
def_ar = np.zeros([len(p0_ar),S])   # Array storing no of defectors 

flag = 0

for h1 in range(len(p0_ar)): 
    p0 = p0_ar[h1]
    for h in range(S):
        
        flag += 1
        rc = 0         # Flag for no of rich cooperators
        rd = 0         # Flag for no of rich defectors
        pd = 0         # Flag for no of poor defectors
        pcop = 0       # Flag for no of poor cooperators
        c_env = 0      # Flag for no of cooperative environments
        d_env = 0      # Flag for no of selfish environments
        eq_env = 0     # Flag for no of neutral environments
        f_c = 0       # Flag for no of cooperators
        f_d = 0        # Flag for no of defectors
        
        G = nx.erdos_renyi_graph(N, pl)
        A = nx.adjacency_matrix(G)
        No_of_rewiring = round((N*(N-1)/2)*re)
        Nre = int(No_of_rewiring)        
        init_wealth_array = np.random.choice(we_arr,N,p=prob_arr) 
        GINI = gini_calc(init_wealth_array)       
            
        for k in range(M):                 # Continuing the game for M rounds
            env_array = np.zeros(N)
            if (k==0):                    # First round  
                
                decision_array = np.zeros(N)
                for i in range(N):         # For all nodes in the network
                    nn = G.degree(i)
                    a = np.random.random()
                    p_in = 0.7
                    if (a <= p_in):
                        decision_array[i] = 1       # Node-i decides to be cooperative                    
                        init_wealth_array[i] = init_wealth_array[i] - co*nn   # Updatation of wealth of a cooperative node
                        for l in range(N):          # Updatation of wealth of its neighbouring nodes
                            if (i==l):
                                continue
                            else:
                                if (A[i,l] == 1):
                                    init_wealth_array[l] = init_wealth_array[l] + be
                                else:
                                    continue

                    else:
                        decision_array[i] = 0          # Node-i decides to be non-cooperative
                        continue   
                              
                
            else:                     # Decision making in subsequent rounds
                new_decision_array = np.zeros(N)
                new_env_array = np.zeros(N)
                for i in range(N):         # For all nodes in the network
                                                        
                    cop = 0                     # Initializing the no of cooperator neighbours
                    for j in range(N):
                        if (A[i,j] == 1):               # If a link exists between nodes i and j
                            if (decision_array[j] == 1):        # If link j cooperated in last round
                                cop += 1
                            elif (decision_array[j] == 0):      # If link j did not cooperate in last round
                                continue
                        else:
                            continue
                
                    sum_neighbor_wealth = 0
                    for j in range(N):			# obtaining total wealth of the neighbors
                        if (A[i,j] == 1):
                            sum_neighbor_wealth += init_wealth_array[j]
                        else:
                            continue
                 
                    if (G.degree(i)>0):                  # For postive number of nearest neighbours
                        av_neighbor_wealth = (sum_neighbor_wealth)/G.degree(i)
                        diff_wealth = av_neighbor_wealth - (init_wealth_array[i])
                        pc = p0 + (1-p0)*(np.tanh(0.001*diff_wealth)) - 0.10 
                                               
                        cop_rat = float(cop/G.degree(i)) 
                        
                        if (cop_rat > 0.5):       # If cooperation parameter is greater than 0.5 i.e cooperative environment
                            
                            c = np.random.random()
                            if (c < pc):
                                new_decision_array[i] = 1       # Node-i decides to be cooperative                          
                            else:
                                new_decision_array[i] = 0

                        elif (cop_rat < 0.5):          # Cooperation parameter is lesser than 0.5 i.e selfish environment
                            
                            c = np.random.random()
                            if (c < pc):                        
                                new_decision_array[i] = 0
                            else:
                                new_decision_array[i] = 1
                            
                        elif (cop_rat == 0.5):        # Neutral environment
                              
                              c = np.random.random()
                              if (c<=pc):
                                  new_decision_array[i] = 1
                              else:
                                  new_decision_array[i] = 0
                                    
                        if (new_decision_array[i]==1):
                            if (diff_wealth<0):
                                rc += 1
                            else:
                                pcop += 1
                        elif (new_decision_array[i]==0): 
                            if (diff_wealth>0):
                                pd += 1
                            else:
                                rd += 1
                                
                    else:
                        new_decision_array[i] = 0                 
                
                # Wealth update
                for i in range(N):
                    if (new_decision_array[i] == 1): 
                        init_wealth_array[i] = init_wealth_array[i] - co*(G.degree(i))   # Updatation of wealth of a cooperative node
                        for l in range(N):          	# Updatation of wealth of its neighbouring nodes
                            if (i==l):
                                continue
                            else:
                                if (A[i,l] == 1):
                                    init_wealth_array[l] = init_wealth_array[l] + be
                                else:
                                    continue
                    else:
                        continue       
                               
                
                
                decision_array = copy.copy(new_decision_array)        
                    
            # Rewiring step
                   
            temp_array = []                                                
            
            while (len(temp_array) < Nre) :            
                i = random.choice(node_arr)
                j = random.choice(node_arr)
                    
                if (i==j):
                    continue
                else:
                
                    if (i,j) in temp_array:
                        continue
                    elif (j,i) in temp_array:
                        continue
                    else:
                        temp_array.append((i,j))
                        temp = [i,j]
                                                             
                        if (A[i,j] == 1):                              # If a link exists between the selected pair
                            b = random.choice(temp)
                            
                            if (b == i):                               # If node-i is given the choice to break or not
                                if (decision_array[j] == 0):
                                    c = np.random.random()
                                    if (c < 0.7):
                                        G.remove_edge(i,j)                 # Breakage of link for node-i disagreeing
                                  
                                    else:
                                        continue                        # Link is kept intact
                                else:
                                    c = np.random.random()
                                    if (c < 0.87):
                                        continue
                                    else:
                                        G.remove_edge(i,j)
                            else:                                   # If node-j is given the choice to break or not	
                                if (decision_array[i] == 0):
                                    c = np.random.random()
                                    if (c < 0.7):                                    
                                        G.remove_edge(i,j)         # Breakage of link for node-j disagreeing
                                    else:
                                        continue			# Link is kept intact
                                else:
                                    c = np.random.random()
                                    if (c < 0.87):
                                        continue
                                    else:
                                        G.remove_edge(i,j)
                                                                
            
                        else:                 # If a link does not exist between the selected pair
                            if (decision_array[i] == 1 and decision_array[j] == 1):
                                c = np.random.random()
                                if (c < 0.93):
                                    G.add_edge(i,j)
                                else:
                                    continue
                            
                            if (decision_array[i] == 0 and decision_array[j] == 0):
                                c = np.random.random()
                                if (c < 0.80):
                                    continue
                                else:
                                    G.add_edge(i,j)
                        
                            if (decision_array[i] == 0 and decision_array[j] == 1):
                                c = np.random.random()
                                if (c < 0.70):
                                    continue
                                else:
                                    G.add_edge(i,j)
                                
                            if (decision_array[i] == 1 and decision_array[j] == 0):
                                c = np.random.random()
                                if (c < 0.70):
                                    continue
                                else:
                                    G.add_edge(i,j)
                                
            A = nx.adjacency_matrix(G)         # Adjacency matrix of the network
            for i in range(N):         # For all nodes in the network                                                   
                    cop = 0                     # Initializing the no of cooperator neighbours
                    for j in range(N):
                        if (A[i,j] == 1):               # If a link exists between nodes i and j
                            if (decision_array[j] == 1):        # If link j cooperated in last round
                                cop += 1
                            elif (decision_array[j] == 0):      # If link j did not cooperate in last round
                                continue
                        else:
                            continue
                    if (G.degree(i)>0):
                        cop_rat = float(cop/G.degree(i))                    
                        if (cop_rat > 0.5):       # If cooperation parameter is greater than 0.5 i.e cooperative environment
                            env_array[i] = 1
                        elif (cop_rat == 0.5):  # Neutral environment
                            env_array[i] = 2
                        elif(cop_rat < 0.5):    # If cooperation parameter is lesser than 0.5 i.e selfish environment
                            env_array[i] = 0
                    else:
                        env_array[i] = 0
                        
            c_env += np.count_nonzero(env_array == 1)
            d_env += np.count_nonzero(env_array == 0)
            eq_env += np.count_nonzero(env_array == 2)
            
        rc_ar[h1,h] = rc 
        pd_ar[h1,h] = pd 
        rd_ar[h1,h] = rd 
        pc_ar[h1,h] = pcop 
        c_env_ar[h1,h] = c_env
        d_env_ar[h1,h] = d_env
        eq_env_ar[h1,h] = eq_env
        coop_ar[h1,h] = rc_ar[h1,h] + pc_ar[h1,h]
        def_ar[h1,h] = pd_ar[h1,h] + rd_ar[h1,h]
        
        yo = (flag*100)/(len(p0_ar)*S)
        print('Job completion percentage: %f' %yo)
        
np.savez('strat_environ_vs_p0', rc_ar=rc_ar, pd_ar=pd_ar, rd_ar=rd_ar, pc_ar=pc_ar, c_env_ar=c_env_ar, d_env_ar=d_env_ar, eq_env_ar=eq_env_ar, coop_ar=coop_ar, def_ar=def_ar)
# Out:
# Job completion percentage: 0.200000
# Job completion percentage: 0.400000
# Job completion percentage: 0.600000
# Job completion percentage: 0.800000
# Job completion percentage: 1.000000
# Job completion percentage: 1.200000
# Job completion percentage: 1.400000
# Job completion percentage: 1.600000
# Job completion percentage: 1.800000
# Job completion percentage: 2.000000
# Job completion percentage: 2.200000
# Job completion percentage: 2.400000
# Job completion percentage: 2.600000
# Job completion percentage: 2.800000
# Job completion percentage: 3.000000
# Job completion percentage: 3.200000
# Job completion percentage: 3.400000
# Job completion percentage: 3.600000
# Job completion percentage: 3.800000
# Job completion percentage: 4.000000
# Job completion percentage: 4.200000
# Job completion percentage: 4.400000
# Job completion percentage: 4.600000
# Job completion percentage: 4.800000
# Job completion percentage: 5.000000
# Job completion percentage: 5.200000
# Job completion percentage: 5.400000
# Job completion percentage: 5.600000
# Job completion percentage: 5.800000
# Job completion percentage: 6.000000
# Job completion percentage: 6.200000
# Job completion percentage: 6.400000
# Job completion percentage: 6.600000
# Job completion percentage: 6.800000
# Job completion percentage: 7.000000
# Job completion percentage: 7.200000
# Job completion percentage: 7.400000
# Job completion percentage: 7.600000
# Job completion percentage: 7.800000
# Job completion percentage: 8.000000
# Job completion percentage: 8.200000
# Job completion percentage: 8.400000
# Job completion percentage: 8.600000
# Job completion percentage: 8.800000
# Job completion percentage: 9.000000
# Job completion percentage: 9.200000
# Job completion percentage: 9.400000
# Job completion percentage: 9.600000
# Job completion percentage: 9.800000
# Job completion percentage: 10.000000
# Job completion percentage: 10.200000
# Job completion percentage: 10.400000
# Job completion percentage: 10.600000
# Job completion percentage: 10.800000
# Job completion percentage: 11.000000
# Job completion percentage: 11.200000
# Job completion percentage: 11.400000
# Job completion percentage: 11.600000
# Job completion percentage: 11.800000
# Job completion percentage: 12.000000
# Job completion percentage: 12.200000
# Job completion percentage: 12.400000
# Job completion percentage: 12.600000
# Job completion percentage: 12.800000
# Job completion percentage: 13.000000
# Job completion percentage: 13.200000
# Job completion percentage: 13.400000
# Job completion percentage: 13.600000
# Job completion percentage: 13.800000
# Job completion percentage: 14.000000
# Job completion percentage: 14.200000
# Job completion percentage: 14.400000
# Job completion percentage: 14.600000
# Job completion percentage: 14.800000
# Job completion percentage: 15.000000
# Job completion percentage: 15.200000
# Job completion percentage: 15.400000
# Job completion percentage: 15.600000
# Job completion percentage: 15.800000
# Job completion percentage: 16.000000
# Job completion percentage: 16.200000
# Job completion percentage: 16.400000
# Job completion percentage: 16.600000
# Job completion percentage: 16.800000
# Job completion percentage: 17.000000
# Job completion percentage: 17.200000
# Job completion percentage: 17.400000
# Job completion percentage: 17.600000
# Job completion percentage: 17.800000
# Job completion percentage: 18.000000
# Job completion percentage: 18.200000
# Job completion percentage: 18.400000
# Job completion percentage: 18.600000
# Job completion percentage: 18.800000
# Job completion percentage: 19.000000
# Job completion percentage: 19.200000
# Job completion percentage: 19.400000
# Job completion percentage: 19.600000
# Job completion percentage: 19.800000
# Job completion percentage: 20.000000
# Job completion percentage: 20.200000
# Job completion percentage: 20.400000
# Job completion percentage: 20.600000
# Job completion percentage: 20.800000
# Job completion percentage: 21.000000
# Job completion percentage: 21.200000
# Job completion percentage: 21.400000
# Job completion percentage: 21.600000
# Job completion percentage: 21.800000
# Job completion percentage: 22.000000
# Job completion percentage: 22.200000
# Job completion percentage: 22.400000
# Job completion percentage: 22.600000
# Job completion percentage: 22.800000
# Job completion percentage: 23.000000
# Job completion percentage: 23.200000
# Job completion percentage: 23.400000
# Job completion percentage: 23.600000
# Job completion percentage: 23.800000
# Job completion percentage: 24.000000
# Job completion percentage: 24.200000
# Job completion percentage: 24.400000
# Job completion percentage: 24.600000
# Job completion percentage: 24.800000
# Job completion percentage: 25.000000
# Job completion percentage: 25.200000
# Job completion percentage: 25.400000
# Job completion percentage: 25.600000
# Job completion percentage: 25.800000
# Job completion percentage: 26.000000
# Job completion percentage: 26.200000
# Job completion percentage: 26.400000
# Job completion percentage: 26.600000
# Job completion percentage: 26.800000
# Job completion percentage: 27.000000
# Job completion percentage: 27.200000
# Job completion percentage: 27.400000
# Job completion percentage: 27.600000
# Job completion percentage: 27.800000
# Job completion percentage: 28.000000
# Job completion percentage: 28.200000
# Job completion percentage: 28.400000
# Job completion percentage: 28.600000
# Job completion percentage: 28.800000
# Job completion percentage: 29.000000
# Job completion percentage: 29.200000
# Job completion percentage: 29.400000
# Job completion percentage: 29.600000
# Job completion percentage: 29.800000
# Job completion percentage: 30.000000
# Job completion percentage: 30.200000
# Job completion percentage: 30.400000
# Job completion percentage: 30.600000
# Job completion percentage: 30.800000
# Job completion percentage: 31.000000
# Job completion percentage: 31.200000
# Job completion percentage: 31.400000
# Job completion percentage: 31.600000
# Job completion percentage: 31.800000
# Job completion percentage: 32.000000
# Job completion percentage: 32.200000
# Job completion percentage: 32.400000
# Job completion percentage: 32.600000
# Job completion percentage: 32.800000
# Job completion percentage: 33.000000
# Job completion percentage: 33.200000
# Job completion percentage: 33.400000
# Job completion percentage: 33.600000
# Job completion percentage: 33.800000
# Job completion percentage: 34.000000
# Job completion percentage: 34.200000
# Job completion percentage: 34.400000
# Job completion percentage: 34.600000
# Job completion percentage: 34.800000
# Job completion percentage: 35.000000
# Job completion percentage: 35.200000
# Job completion percentage: 35.400000
# Job completion percentage: 35.600000
# Job completion percentage: 35.800000
# Job completion percentage: 36.000000
# Job completion percentage: 36.200000
# Job completion percentage: 36.400000
# Job completion percentage: 36.600000
# Job completion percentage: 36.800000
# Job completion percentage: 37.000000
# Job completion percentage: 37.200000
# Job completion percentage: 37.400000
# Job completion percentage: 37.600000
# Job completion percentage: 37.800000
# Job completion percentage: 38.000000
# Job completion percentage: 38.200000
# Job completion percentage: 38.400000
# Job completion percentage: 38.600000
# Job completion percentage: 38.800000
# Job completion percentage: 39.000000
# Job completion percentage: 39.200000
# Job completion percentage: 39.400000
# Job completion percentage: 39.600000
# Job completion percentage: 39.800000
# Job completion percentage: 40.000000
# Job completion percentage: 40.200000
# Job completion percentage: 40.400000
# Job completion percentage: 40.600000
# Job completion percentage: 40.800000
# Job completion percentage: 41.000000
# Job completion percentage: 41.200000
# Job completion percentage: 41.400000
# Job completion percentage: 41.600000
# Job completion percentage: 41.800000
# Job completion percentage: 42.000000
# Job completion percentage: 42.200000
# Job completion percentage: 42.400000
# Job completion percentage: 42.600000
# Job completion percentage: 42.800000
# Job completion percentage: 43.000000
# Job completion percentage: 43.200000
# Job completion percentage: 43.400000
# Job completion percentage: 43.600000
# Job completion percentage: 43.800000
# Job completion percentage: 44.000000
# Job completion percentage: 44.200000
# Job completion percentage: 44.400000
# Job completion percentage: 44.600000
# Job completion percentage: 44.800000
# Job completion percentage: 45.000000
# Job completion percentage: 45.200000
# Job completion percentage: 45.400000
# Job completion percentage: 45.600000
# Job completion percentage: 45.800000
# Job completion percentage: 46.000000
# Job completion percentage: 46.200000
# Job completion percentage: 46.400000
# Job completion percentage: 46.600000
# Job completion percentage: 46.800000
# Job completion percentage: 47.000000
# Job completion percentage: 47.200000
# Job completion percentage: 47.400000
# Job completion percentage: 47.600000
# Job completion percentage: 47.800000
# Job completion percentage: 48.000000
# Job completion percentage: 48.200000
# Job completion percentage: 48.400000
# Job completion percentage: 48.600000
# Job completion percentage: 48.800000
# Job completion percentage: 49.000000
# Job completion percentage: 49.200000
# Job completion percentage: 49.400000
# Job completion percentage: 49.600000
# Job completion percentage: 49.800000
# Job completion percentage: 50.000000
# Job completion percentage: 50.200000
# Job completion percentage: 50.400000
# Job completion percentage: 50.600000
# Job completion percentage: 50.800000
# Job completion percentage: 51.000000
# Job completion percentage: 51.200000
# Job completion percentage: 51.400000
# Job completion percentage: 51.600000
# Job completion percentage: 51.800000
# Job completion percentage: 52.000000
# Job completion percentage: 52.200000
# Job completion percentage: 52.400000
# Job completion percentage: 52.600000
# Job completion percentage: 52.800000
# Job completion percentage: 53.000000
# Job completion percentage: 53.200000
# Job completion percentage: 53.400000
# Job completion percentage: 53.600000
# Job completion percentage: 53.800000
# Job completion percentage: 54.000000
# Job completion percentage: 54.200000
# Job completion percentage: 54.400000
# Job completion percentage: 54.600000
# Job completion percentage: 54.800000
# Job completion percentage: 55.000000
# Job completion percentage: 55.200000
# Job completion percentage: 55.400000
# Job completion percentage: 55.600000
# Job completion percentage: 55.800000
# Job completion percentage: 56.000000
# Job completion percentage: 56.200000
# Job completion percentage: 56.400000
# Job completion percentage: 56.600000
# Job completion percentage: 56.800000
# Job completion percentage: 57.000000
# Job completion percentage: 57.200000
# Job completion percentage: 57.400000
# Job completion percentage: 57.600000
# Job completion percentage: 57.800000
# Job completion percentage: 58.000000
# Job completion percentage: 58.200000
# Job completion percentage: 58.400000
# Job completion percentage: 58.600000
# Job completion percentage: 58.800000
# Job completion percentage: 59.000000
# Job completion percentage: 59.200000
# Job completion percentage: 59.400000
# Job completion percentage: 59.600000
# Job completion percentage: 59.800000
# Job completion percentage: 60.000000
# Job completion percentage: 60.200000
# Job completion percentage: 60.400000
# Job completion percentage: 60.600000
# Job completion percentage: 60.800000
# Job completion percentage: 61.000000
# Job completion percentage: 61.200000
# Job completion percentage: 61.400000
# Job completion percentage: 61.600000
# Job completion percentage: 61.800000
# Job completion percentage: 62.000000
# Job completion percentage: 62.200000
# Job completion percentage: 62.400000
# Job completion percentage: 62.600000
# Job completion percentage: 62.800000
# Job completion percentage: 63.000000
# Job completion percentage: 63.200000
# Job completion percentage: 63.400000
# Job completion percentage: 63.600000
# Job completion percentage: 63.800000
# Job completion percentage: 64.000000
# Job completion percentage: 64.200000
# Job completion percentage: 64.400000
# Job completion percentage: 64.600000
# Job completion percentage: 64.800000
# Job completion percentage: 65.000000
# Job completion percentage: 65.200000
# Job completion percentage: 65.400000
# Job completion percentage: 65.600000
# Job completion percentage: 65.800000
# Job completion percentage: 66.000000
# Job completion percentage: 66.200000
# Job completion percentage: 66.400000
# Job completion percentage: 66.600000
# Job completion percentage: 66.800000
# Job completion percentage: 67.000000
# Job completion percentage: 67.200000
# Job completion percentage: 67.400000
# Job completion percentage: 67.600000
# Job completion percentage: 67.800000
# Job completion percentage: 68.000000
# Job completion percentage: 68.200000
# Job completion percentage: 68.400000
# Job completion percentage: 68.600000
# Job completion percentage: 68.800000
# Job completion percentage: 69.000000
# Job completion percentage: 69.200000
# Job completion percentage: 69.400000
# Job completion percentage: 69.600000
# Job completion percentage: 69.800000
# Job completion percentage: 70.000000
# Job completion percentage: 70.200000
# Job completion percentage: 70.400000
# Job completion percentage: 70.600000
# Job completion percentage: 70.800000
# Job completion percentage: 71.000000
# Job completion percentage: 71.200000
# Job completion percentage: 71.400000
# Job completion percentage: 71.600000
# Job completion percentage: 71.800000
# Job completion percentage: 72.000000
# Job completion percentage: 72.200000
# Job completion percentage: 72.400000
# Job completion percentage: 72.600000
# Job completion percentage: 72.800000
# Job completion percentage: 73.000000
# Job completion percentage: 73.200000
# Job completion percentage: 73.400000
# Job completion percentage: 73.600000
# Job completion percentage: 73.800000
# Job completion percentage: 74.000000
# Job completion percentage: 74.200000
# Job completion percentage: 74.400000
# Job completion percentage: 74.600000
# Job completion percentage: 74.800000
# Job completion percentage: 75.000000
# Job completion percentage: 75.200000
# Job completion percentage: 75.400000
# Job completion percentage: 75.600000
# Job completion percentage: 75.800000
# Job completion percentage: 76.000000
# Job completion percentage: 76.200000
# Job completion percentage: 76.400000
# Job completion percentage: 76.600000
# Job completion percentage: 76.800000
# Job completion percentage: 77.000000
# Job completion percentage: 77.200000
# Job completion percentage: 77.400000
# Job completion percentage: 77.600000
# Job completion percentage: 77.800000
# Job completion percentage: 78.000000
# Job completion percentage: 78.200000
# Job completion percentage: 78.400000
# Job completion percentage: 78.600000
# Job completion percentage: 78.800000
# Job completion percentage: 79.000000
# Job completion percentage: 79.200000
# Job completion percentage: 79.400000
# Job completion percentage: 79.600000
# Job completion percentage: 79.800000
# Job completion percentage: 80.000000
# Job completion percentage: 80.200000
# Job completion percentage: 80.400000
# Job completion percentage: 80.600000
# Job completion percentage: 80.800000
# Job completion percentage: 81.000000
# Job completion percentage: 81.200000
# Job completion percentage: 81.400000
# Job completion percentage: 81.600000
# Job completion percentage: 81.800000
# Job completion percentage: 82.000000
# Job completion percentage: 82.200000
# Job completion percentage: 82.400000
# Job completion percentage: 82.600000
# Job completion percentage: 82.800000
# Job completion percentage: 83.000000
# Job completion percentage: 83.200000
# Job completion percentage: 83.400000
# Job completion percentage: 83.600000
# Job completion percentage: 83.800000
# Job completion percentage: 84.000000
# Job completion percentage: 84.200000
# Job completion percentage: 84.400000
# Job completion percentage: 84.600000
# Job completion percentage: 84.800000
# Job completion percentage: 85.000000
# Job completion percentage: 85.200000
# Job completion percentage: 85.400000
# Job completion percentage: 85.600000
# Job completion percentage: 85.800000
# Job completion percentage: 86.000000
# Job completion percentage: 86.200000
# Job completion percentage: 86.400000
# Job completion percentage: 86.600000
# Job completion percentage: 86.800000
# Job completion percentage: 87.000000
# Job completion percentage: 87.200000
# Job completion percentage: 87.400000
# Job completion percentage: 87.600000
# Job completion percentage: 87.800000
# Job completion percentage: 88.000000
# Job completion percentage: 88.200000
# Job completion percentage: 88.400000
# Job completion percentage: 88.600000
# Job completion percentage: 88.800000
# Job completion percentage: 89.000000
# Job completion percentage: 89.200000
# Job completion percentage: 89.400000
# Job completion percentage: 89.600000
# Job completion percentage: 89.800000
# Job completion percentage: 90.000000
# Job completion percentage: 90.200000
# Job completion percentage: 90.400000
# Job completion percentage: 90.600000
# Job completion percentage: 90.800000
# Job completion percentage: 91.000000
# Job completion percentage: 91.200000
# Job completion percentage: 91.400000
# Job completion percentage: 91.600000
# Job completion percentage: 91.800000
# Job completion percentage: 92.000000
# Job completion percentage: 92.200000
# Job completion percentage: 92.400000
# Job completion percentage: 92.600000
# Job completion percentage: 92.800000
# Job completion percentage: 93.000000
# Job completion percentage: 93.200000
# Job completion percentage: 93.400000
# Job completion percentage: 93.600000
# Job completion percentage: 93.800000
# Job completion percentage: 94.000000
# Job completion percentage: 94.200000
# Job completion percentage: 94.400000
# Job completion percentage: 94.600000
# Job completion percentage: 94.800000
# Job completion percentage: 95.000000
# Job completion percentage: 95.200000
# Job completion percentage: 95.400000
# Job completion percentage: 95.600000
# Job completion percentage: 95.800000
# Job completion percentage: 96.000000
# Job completion percentage: 96.200000
# Job completion percentage: 96.400000
# Job completion percentage: 96.600000
# Job completion percentage: 96.800000
# Job completion percentage: 97.000000
# Job completion percentage: 97.200000
# Job completion percentage: 97.400000
# Job completion percentage: 97.600000
# Job completion percentage: 97.800000
# Job completion percentage: 98.000000
# Job completion percentage: 98.200000
# Job completion percentage: 98.400000
# Job completion percentage: 98.600000
# Job completion percentage: 98.800000
# Job completion percentage: 99.000000
# Job completion percentage: 99.200000
# Job completion percentage: 99.400000
# Job completion percentage: 99.600000
# Job completion percentage: 99.800000
# Job completion percentage: 100.000000
