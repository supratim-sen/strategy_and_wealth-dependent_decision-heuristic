# %%
from __future__ import division
import networkx as nx
import matplotlib.pyplot as plt
import pylab
import scipy as sp
import numpy as np
import itertools
import copy
import math
import random

N =  50                  # Number of nodes
rw = 700                 # Wealth value of rich
pw = 300                # Wealth value of poor
we_arr = [rw, pw]       # Array storing both the wealth values
pr = 0.5                # Probability of being rich
prob_arr = [pr, 1-pr]  # Array storing probability of wealth allotment values
M = 20                  # Number of rounds
co = 50                 # Unitary Cost of co-operation
be = 100                # Unitary Benefit of co-operation
S = 100                  # Number of iterations
pl = 0.3                # Initial probability of a link being formed between any two nodes

p0_arr = [0.55,0.7,0.9]
re_arr = [0,0.3,0.6]

def inv_logit(y):
    inv_logit_out =(np.exp(y)/(1+np.exp(y)))
    return inv_logit_out

def gini_calc(x):       #IN: Wealth values across the population, OUT: Gini Coefficient
    sum2=0
    for i in range(len(x)):
        sum1=0
        for j in range(len(x)):
            sum1=sum1+np.abs(x[i]-x[j])
        sum2=sum2+sum1;
    
    gini=sum2/(2*len(x)**2*np.mean(x));
    return gini

node_arr = np.arange(N)

c_ar = np.zeros([len(p0_arr),len(re_arr),S,M])     # Array storing number of cooperative environments
d_ar = np.zeros([len(p0_arr),len(re_arr),S,M])     # Array storing number of selfish environments
eq_ar = np.zeros([len(p0_arr),len(re_arr),S,M])   # Array storing number of neutral environments

flag = 0

for h1 in range(len(re_arr)):    
    re = re_arr[h1]
    for h2 in range(len(p0_arr)):
        p0 = p0_arr[h2]
        for h in range(S):
            # Initializing the counts
            c_env = 0
            d_env = 0
            eq_env = 0

            G = nx.erdos_renyi_graph(N, pl)
            A = nx.adjacency_matrix(G)
            E = G.number_of_edges()
            No_of_pairs = (N*(N-1))/2
            No_of_rewiring = round(No_of_pairs*re)
            Nre = int(No_of_rewiring)

            init_wealth_array = np.random.choice(we_arr,N,p=prob_arr)             

            for k in range(M):                 # Continuing the game for M rounds
                c_env = 0
                d_env = 0
                eq_env = 0

                if (k==0):                    # First round 
                    p_in = 0.7
                    decision_array = np.zeros(N)
                    for i in range(N):         # For all nodes in the network
                        nn = G.degree(i)
                        a = np.random.random()

                        if (a <= p_in):
                            decision_array[i] = 1       # Node-i decides to be cooperative                    
                            init_wealth_array[i] = init_wealth_array[i] - co*nn   # Updatation of wealth of a cooperative node
                            for l in range(N):          # Updatation of wealth of its neighbouring nodes
                                if (i==l):
                                    continue
                                else:
                                    if (A[i,l] == 1):
                                        init_wealth_array[l] = init_wealth_array[l] + be
                                    else:
                                        continue

                        else:
                            decision_array[i] = 0          # Node-i decides to be non-cooperative
                            continue                  


                else:                     # Decision making in subsequent rounds
                    new_decision_array = np.zeros(N)

                    for i in range(N):         # For all nodes in the network
                        nn = G.degree(i)                                    
                        cop = 0                     # Initializing the no of cooperator neighbours
                        for j in range(N):
                            if (A[i,j] == 1):               # If a link exists between nodes i and j
                                if (decision_array[j] == 1):        # If link j cooperated in last round
                                    cop += 1
                                elif (decision_array[j] == 0):      # If link j did not cooperate in last round
                                    continue
                            else:
                                continue

                        sum_neighbor_wealth = 0
                        for j in range(N):			# Total wealth of the neighbors
                            if (A[i,j] == 1):
                                sum_neighbor_wealth += init_wealth_array[j]
                            else:
                                continue

                        if (nn>0):
                            av_neighbor_wealth = (sum_neighbor_wealth)/nn
                            diff_wealth = av_neighbor_wealth - (init_wealth_array[i])
                            pc = p0 + (1-p0)*(np.tanh(0.001*diff_wealth)) - 0.10 
                        else:
                            pc = p0                   


                        if (nn>0):              # For postive number of nearest neighbours
                            cop_rat = float(cop/nn)                    
                            if (cop_rat > 0.5):       # If cooperation parameter is greater than 0.5 i.e. cooperative environment

                                c = np.random.random()
                                if (c < pc):
                                    new_decision_array[i] = 1       # Node-i decides to be cooperative                          
                                else:
                                    new_decision_array[i] = 0

                            elif (cop_rat < 0.5):          # Cooperation parameter is lesser than 0.5 i.e. defective environment

                                c = np.random.random()
                                if (c < pc):                        
                                    new_decision_array[i] = 0
                                else:
                                    new_decision_array[i] = 1

                            elif (cop_rat == 0.5):       # Neutral environment

                                  c = np.random.random()
                                  if (c<=pc):
                                      new_decision_array[i] = 1
                                  else:
                                      new_decision_array[i] = 0

                        else:
                            new_decision_array[i] = 0

                    for i in range(N):
                        if (new_decision_array[i] == 1): 
                            init_wealth_array[i] = init_wealth_array[i] - co*(G.degree(i))   # Updatation of wealth of a cooperative node
                            for l in range(N):          	# Updatation of wealth of its neighbouring nodes
                                if (i==l):
                                    continue
                                else:
                                    if (A[i,l] == 1):
                                        init_wealth_array[l] = init_wealth_array[l] + be
                                    else:
                                        continue
                        else:
                            continue       


                    decision_array = copy.copy(new_decision_array)         

                # Rewiring step

                temp_array = []


                while (len(temp_array) < Nre) :            
                    i = random.choice(node_arr)
                    j = random.choice(node_arr)

                    if (i==j):
                        continue
                    else:

                        if (i,j) in temp_array:
                            continue
                        elif (j,i) in temp_array:
                            continue
                        else:
                            temp_array.append((i,j))
                            temp = [i,j]

                            if (A[i,j] == 1):                              # If a link exists between the selected pair
                                b = random.choice(temp)

                                if (b == i):                               # If node-i is given the choice to break or not
                                    if (decision_array[j] == 0):
                                        c = np.random.random()
                                        if (c < 0.7):
                                            G.remove_edge(i,j)                 # Breakage of link for node-i disagreeing

                                        else:
                                            continue                        # Link is kept intact
                                    else:
                                        c = np.random.random()
                                        if (c < 0.87):
                                            continue
                                        else:
                                            G.remove_edge(i,j)
                                else:                                   # If node-j is given the choice to break or not	
                                    if (decision_array[i] == 0):
                                        c = np.random.random()
                                        if (c < 0.7):                                    
                                            G.remove_edge(i,j)         # Breakage of link for node-j disagreeing
                                        else:
                                            continue			# Link is kept intact
                                    else:
                                        c = np.random.random()
                                        if (c < 0.87):
                                            continue
                                        else:
                                            G.remove_edge(i,j)


                            else:                 # If a link does not exist between the selected pair
                                if (decision_array[i] == 1 and decision_array[j] == 1):
                                    c = np.random.random()
                                    if (c < 0.93):
                                        G.add_edge(i,j)
                                    else:
                                        continue

                                if (decision_array[i] == 0 and decision_array[j] == 0):
                                    c = np.random.random()
                                    if (c < 0.8):
                                        continue
                                    else:
                                        G.add_edge(i,j)

                                if (decision_array[i] == 0 and decision_array[j] == 1):
                                    c = np.random.random()
                                    if (c < 0.7):
                                        continue
                                    else:
                                        G.add_edge(i,j)

                                if (decision_array[i] == 1 and decision_array[j] == 0):
                                    c = np.random.random()
                                    if (c < 0.7):
                                        continue
                                    else:
                                        G.add_edge(i,j)

                A = nx.adjacency_matrix(G)     # Adjacency matrix of the network

                for i in range(N):         # For all nodes in the network                                                   
                    cop = 0                     # Initializing the no of cooperator neighbours
                    for j in range(N):
                        if (A[i,j] == 1):               # If a link exists between nodes i and j
                            if (decision_array[j] == 1):        # If link j cooperated in last round
                                cop += 1
                            elif (decision_array[j] == 0):      # If link j did not cooperate in last round
                                continue
                        else:
                            continue
                    if (G.degree(i)>0):
                        cop_rat = float(cop/G.degree(i))                    
                        if (cop_rat > 0.5):       # If cooperation parameter is greater than 0.5
                                c_env += 1
                        elif (cop_rat == 0.5):     # Neutral environment
                                eq_env += 1
                        elif(cop_rat < 0.5):       # Selfish environment
                                d_env += 1
                    else:
                            d_env += 1      # A node without any bonds is assumed to be in a selfish environment

                c_ar[h2,h1,h,k] = c_env
                d_ar[h2,h1,h,k] = d_env
                eq_ar[h2,h1,h,k] = eq_env

            flag += 1
            yo = (flag*100)/(len(re_arr)*S*len(p0_arr))

            print('Job completion percentage: %f' %yo)

np.savez('Supl-4', c_ar=c_ar,d_ar=d_ar,eq_ar=eq_ar)
# Out:
# Job completion percentage: 0.111111
# Job completion percentage: 0.222222
# Job completion percentage: 0.333333
# Job completion percentage: 0.444444
# Job completion percentage: 0.555556
# Job completion percentage: 0.666667
# Job completion percentage: 0.777778
# Job completion percentage: 0.888889
# Job completion percentage: 1.000000
# Job completion percentage: 1.111111
# Job completion percentage: 1.222222
# Job completion percentage: 1.333333
# Job completion percentage: 1.444444
# Job completion percentage: 1.555556
# Job completion percentage: 1.666667
# Job completion percentage: 1.777778
# Job completion percentage: 1.888889
# Job completion percentage: 2.000000
# Job completion percentage: 2.111111
# Job completion percentage: 2.222222
# Job completion percentage: 2.333333
# Job completion percentage: 2.444444
# Job completion percentage: 2.555556
# Job completion percentage: 2.666667
# Job completion percentage: 2.777778
# Job completion percentage: 2.888889
# Job completion percentage: 3.000000
# Job completion percentage: 3.111111
# Job completion percentage: 3.222222
# Job completion percentage: 3.333333
# Job completion percentage: 3.444444
# Job completion percentage: 3.555556
# Job completion percentage: 3.666667
# Job completion percentage: 3.777778
# Job completion percentage: 3.888889
# Job completion percentage: 4.000000
# Job completion percentage: 4.111111
# Job completion percentage: 4.222222
# Job completion percentage: 4.333333
# Job completion percentage: 4.444444
# Job completion percentage: 4.555556
# Job completion percentage: 4.666667
# Job completion percentage: 4.777778
# Job completion percentage: 4.888889
# Job completion percentage: 5.000000
# Job completion percentage: 5.111111
# Job completion percentage: 5.222222
# Job completion percentage: 5.333333
# Job completion percentage: 5.444444
# Job completion percentage: 5.555556
# Job completion percentage: 5.666667
# Job completion percentage: 5.777778
# Job completion percentage: 5.888889
# Job completion percentage: 6.000000
# Job completion percentage: 6.111111
# Job completion percentage: 6.222222
# Job completion percentage: 6.333333
# Job completion percentage: 6.444444
# Job completion percentage: 6.555556
# Job completion percentage: 6.666667
# Job completion percentage: 6.777778
# Job completion percentage: 6.888889
# Job completion percentage: 7.000000
# Job completion percentage: 7.111111
# Job completion percentage: 7.222222
# Job completion percentage: 7.333333
# Job completion percentage: 7.444444
# Job completion percentage: 7.555556
# Job completion percentage: 7.666667
# Job completion percentage: 7.777778
# Job completion percentage: 7.888889
# Job completion percentage: 8.000000
# Job completion percentage: 8.111111
# Job completion percentage: 8.222222
# Job completion percentage: 8.333333
# Job completion percentage: 8.444444
# Job completion percentage: 8.555556
# Job completion percentage: 8.666667
# Job completion percentage: 8.777778
# Job completion percentage: 8.888889
# Job completion percentage: 9.000000
# Job completion percentage: 9.111111
# Job completion percentage: 9.222222
# Job completion percentage: 9.333333
# Job completion percentage: 9.444444
# Job completion percentage: 9.555556
# Job completion percentage: 9.666667
# Job completion percentage: 9.777778
# Job completion percentage: 9.888889
# Job completion percentage: 10.000000
# Job completion percentage: 10.111111
# Job completion percentage: 10.222222
# Job completion percentage: 10.333333
# Job completion percentage: 10.444444
# Job completion percentage: 10.555556
# Job completion percentage: 10.666667
# Job completion percentage: 10.777778
# Job completion percentage: 10.888889
# Job completion percentage: 11.000000
# Job completion percentage: 11.111111
# Job completion percentage: 11.222222
# Job completion percentage: 11.333333
# Job completion percentage: 11.444444
# Job completion percentage: 11.555556
# Job completion percentage: 11.666667
# Job completion percentage: 11.777778
# Job completion percentage: 11.888889
# Job completion percentage: 12.000000
# Job completion percentage: 12.111111
# Job completion percentage: 12.222222
# Job completion percentage: 12.333333
# Job completion percentage: 12.444444
# Job completion percentage: 12.555556
# Job completion percentage: 12.666667
# Job completion percentage: 12.777778
# Job completion percentage: 12.888889
# Job completion percentage: 13.000000
# Job completion percentage: 13.111111
# Job completion percentage: 13.222222
# Job completion percentage: 13.333333
# Job completion percentage: 13.444444
# Job completion percentage: 13.555556
# Job completion percentage: 13.666667
# Job completion percentage: 13.777778
# Job completion percentage: 13.888889
# Job completion percentage: 14.000000
# Job completion percentage: 14.111111
# Job completion percentage: 14.222222
# Job completion percentage: 14.333333
# Job completion percentage: 14.444444
# Job completion percentage: 14.555556
# Job completion percentage: 14.666667
# Job completion percentage: 14.777778
# Job completion percentage: 14.888889
# Job completion percentage: 15.000000
# Job completion percentage: 15.111111
# Job completion percentage: 15.222222
# Job completion percentage: 15.333333
# Job completion percentage: 15.444444
# Job completion percentage: 15.555556
# Job completion percentage: 15.666667
# Job completion percentage: 15.777778
# Job completion percentage: 15.888889
# Job completion percentage: 16.000000
# Job completion percentage: 16.111111
# Job completion percentage: 16.222222
# Job completion percentage: 16.333333
# Job completion percentage: 16.444444
# Job completion percentage: 16.555556
# Job completion percentage: 16.666667
# Job completion percentage: 16.777778
# Job completion percentage: 16.888889
# Job completion percentage: 17.000000
# Job completion percentage: 17.111111
# Job completion percentage: 17.222222
# Job completion percentage: 17.333333
# Job completion percentage: 17.444444
# Job completion percentage: 17.555556
# Job completion percentage: 17.666667
# Job completion percentage: 17.777778
# Job completion percentage: 17.888889
# Job completion percentage: 18.000000
# Job completion percentage: 18.111111
# Job completion percentage: 18.222222
# Job completion percentage: 18.333333
# Job completion percentage: 18.444444
# Job completion percentage: 18.555556
# Job completion percentage: 18.666667
# Job completion percentage: 18.777778
# Job completion percentage: 18.888889
# Job completion percentage: 19.000000
# Job completion percentage: 19.111111
# Job completion percentage: 19.222222
# Job completion percentage: 19.333333
# Job completion percentage: 19.444444
# Job completion percentage: 19.555556
# Job completion percentage: 19.666667
# Job completion percentage: 19.777778
# Job completion percentage: 19.888889
# Job completion percentage: 20.000000
# Job completion percentage: 20.111111
# Job completion percentage: 20.222222
# Job completion percentage: 20.333333
# Job completion percentage: 20.444444
# Job completion percentage: 20.555556
# Job completion percentage: 20.666667
# Job completion percentage: 20.777778
# Job completion percentage: 20.888889
# Job completion percentage: 21.000000
# Job completion percentage: 21.111111
# Job completion percentage: 21.222222
# Job completion percentage: 21.333333
# Job completion percentage: 21.444444
# Job completion percentage: 21.555556
# Job completion percentage: 21.666667
# Job completion percentage: 21.777778
# Job completion percentage: 21.888889
# Job completion percentage: 22.000000
# Job completion percentage: 22.111111
# Job completion percentage: 22.222222
# Job completion percentage: 22.333333
# Job completion percentage: 22.444444
# Job completion percentage: 22.555556
# Job completion percentage: 22.666667
# Job completion percentage: 22.777778
# Job completion percentage: 22.888889
# Job completion percentage: 23.000000
# Job completion percentage: 23.111111
# Job completion percentage: 23.222222
# Job completion percentage: 23.333333
# Job completion percentage: 23.444444
# Job completion percentage: 23.555556
# Job completion percentage: 23.666667
# Job completion percentage: 23.777778
# Job completion percentage: 23.888889
# Job completion percentage: 24.000000
# Job completion percentage: 24.111111
# Job completion percentage: 24.222222
# Job completion percentage: 24.333333
# Job completion percentage: 24.444444
# Job completion percentage: 24.555556
# Job completion percentage: 24.666667
# Job completion percentage: 24.777778
# Job completion percentage: 24.888889
# Job completion percentage: 25.000000
# Job completion percentage: 25.111111
# Job completion percentage: 25.222222
# Job completion percentage: 25.333333
# Job completion percentage: 25.444444
# Job completion percentage: 25.555556
# Job completion percentage: 25.666667
# Job completion percentage: 25.777778
# Job completion percentage: 25.888889
# Job completion percentage: 26.000000
# Job completion percentage: 26.111111
# Job completion percentage: 26.222222
# Job completion percentage: 26.333333
# Job completion percentage: 26.444444
# Job completion percentage: 26.555556
# Job completion percentage: 26.666667
# Job completion percentage: 26.777778
# Job completion percentage: 26.888889
# Job completion percentage: 27.000000
# Job completion percentage: 27.111111
# Job completion percentage: 27.222222
# Job completion percentage: 27.333333
# Job completion percentage: 27.444444
# Job completion percentage: 27.555556
# Job completion percentage: 27.666667
# Job completion percentage: 27.777778
# Job completion percentage: 27.888889
# Job completion percentage: 28.000000
# Job completion percentage: 28.111111
# Job completion percentage: 28.222222
# Job completion percentage: 28.333333
# Job completion percentage: 28.444444
# Job completion percentage: 28.555556
# Job completion percentage: 28.666667
# Job completion percentage: 28.777778
# Job completion percentage: 28.888889
# Job completion percentage: 29.000000
# Job completion percentage: 29.111111
# Job completion percentage: 29.222222
# Job completion percentage: 29.333333
# Job completion percentage: 29.444444
# Job completion percentage: 29.555556
# Job completion percentage: 29.666667
# Job completion percentage: 29.777778
# Job completion percentage: 29.888889
# Job completion percentage: 30.000000
# Job completion percentage: 30.111111
# Job completion percentage: 30.222222
# Job completion percentage: 30.333333
# Job completion percentage: 30.444444
# Job completion percentage: 30.555556
# Job completion percentage: 30.666667
# Job completion percentage: 30.777778
# Job completion percentage: 30.888889
# Job completion percentage: 31.000000
# Job completion percentage: 31.111111
# Job completion percentage: 31.222222
# Job completion percentage: 31.333333
# Job completion percentage: 31.444444
# Job completion percentage: 31.555556
# Job completion percentage: 31.666667
# Job completion percentage: 31.777778
# Job completion percentage: 31.888889
# Job completion percentage: 32.000000
# Job completion percentage: 32.111111
# Job completion percentage: 32.222222
# Job completion percentage: 32.333333
# Job completion percentage: 32.444444
# Job completion percentage: 32.555556
# Job completion percentage: 32.666667
# Job completion percentage: 32.777778
# Job completion percentage: 32.888889
# Job completion percentage: 33.000000
# Job completion percentage: 33.111111
# Job completion percentage: 33.222222
# Job completion percentage: 33.333333
# Job completion percentage: 33.444444
# Job completion percentage: 33.555556
# Job completion percentage: 33.666667
# Job completion percentage: 33.777778
# Job completion percentage: 33.888889
# Job completion percentage: 34.000000
# Job completion percentage: 34.111111
# Job completion percentage: 34.222222
# Job completion percentage: 34.333333
# Job completion percentage: 34.444444
# Job completion percentage: 34.555556
# Job completion percentage: 34.666667
# Job completion percentage: 34.777778
# Job completion percentage: 34.888889
# Job completion percentage: 35.000000
# Job completion percentage: 35.111111
# Job completion percentage: 35.222222
# Job completion percentage: 35.333333
# Job completion percentage: 35.444444
# Job completion percentage: 35.555556
# Job completion percentage: 35.666667
# Job completion percentage: 35.777778
# Job completion percentage: 35.888889
# Job completion percentage: 36.000000
# Job completion percentage: 36.111111
# Job completion percentage: 36.222222
# Job completion percentage: 36.333333
# Job completion percentage: 36.444444
# Job completion percentage: 36.555556
# Job completion percentage: 36.666667
# Job completion percentage: 36.777778
# Job completion percentage: 36.888889
# Job completion percentage: 37.000000
# Job completion percentage: 37.111111
# Job completion percentage: 37.222222
# Job completion percentage: 37.333333
# Job completion percentage: 37.444444
# Job completion percentage: 37.555556
# Job completion percentage: 37.666667
# Job completion percentage: 37.777778
# Job completion percentage: 37.888889
# Job completion percentage: 38.000000
# Job completion percentage: 38.111111
# Job completion percentage: 38.222222
# Job completion percentage: 38.333333
# Job completion percentage: 38.444444
# Job completion percentage: 38.555556
# Job completion percentage: 38.666667
# Job completion percentage: 38.777778
# Job completion percentage: 38.888889
# Job completion percentage: 39.000000
# Job completion percentage: 39.111111
# Job completion percentage: 39.222222
# Job completion percentage: 39.333333
# Job completion percentage: 39.444444
# Job completion percentage: 39.555556
# Job completion percentage: 39.666667
# Job completion percentage: 39.777778
# Job completion percentage: 39.888889
# Job completion percentage: 40.000000
# Job completion percentage: 40.111111
# Job completion percentage: 40.222222
# Job completion percentage: 40.333333
# Job completion percentage: 40.444444
# Job completion percentage: 40.555556
# Job completion percentage: 40.666667
# Job completion percentage: 40.777778
# Job completion percentage: 40.888889
# Job completion percentage: 41.000000
# Job completion percentage: 41.111111
# Job completion percentage: 41.222222
# Job completion percentage: 41.333333
# Job completion percentage: 41.444444
# Job completion percentage: 41.555556
# Job completion percentage: 41.666667
# Job completion percentage: 41.777778
# Job completion percentage: 41.888889
# Job completion percentage: 42.000000
# Job completion percentage: 42.111111
# Job completion percentage: 42.222222
# Job completion percentage: 42.333333
# Job completion percentage: 42.444444
# Job completion percentage: 42.555556
# Job completion percentage: 42.666667
# Job completion percentage: 42.777778
# Job completion percentage: 42.888889
# Job completion percentage: 43.000000
# Job completion percentage: 43.111111
# Job completion percentage: 43.222222
# Job completion percentage: 43.333333
# Job completion percentage: 43.444444
# Job completion percentage: 43.555556
# Job completion percentage: 43.666667
# Job completion percentage: 43.777778
# Job completion percentage: 43.888889
# Job completion percentage: 44.000000
# Job completion percentage: 44.111111
# Job completion percentage: 44.222222
# Job completion percentage: 44.333333
# Job completion percentage: 44.444444
# Job completion percentage: 44.555556
# Job completion percentage: 44.666667
# Job completion percentage: 44.777778
# Job completion percentage: 44.888889
# Job completion percentage: 45.000000
# Job completion percentage: 45.111111
# Job completion percentage: 45.222222
# Job completion percentage: 45.333333
# Job completion percentage: 45.444444
# Job completion percentage: 45.555556
# Job completion percentage: 45.666667
# Job completion percentage: 45.777778
# Job completion percentage: 45.888889
# Job completion percentage: 46.000000
# Job completion percentage: 46.111111
# Job completion percentage: 46.222222
# Job completion percentage: 46.333333
# Job completion percentage: 46.444444
# Job completion percentage: 46.555556
# Job completion percentage: 46.666667
# Job completion percentage: 46.777778
# Job completion percentage: 46.888889
# Job completion percentage: 47.000000
# Job completion percentage: 47.111111
# Job completion percentage: 47.222222
# Job completion percentage: 47.333333
# Job completion percentage: 47.444444
# Job completion percentage: 47.555556
# Job completion percentage: 47.666667
# Job completion percentage: 47.777778
# Job completion percentage: 47.888889
# Job completion percentage: 48.000000
# Job completion percentage: 48.111111
# Job completion percentage: 48.222222
# Job completion percentage: 48.333333
# Job completion percentage: 48.444444
# Job completion percentage: 48.555556
# Job completion percentage: 48.666667
# Job completion percentage: 48.777778
# Job completion percentage: 48.888889
# Job completion percentage: 49.000000
# Job completion percentage: 49.111111
# Job completion percentage: 49.222222
# Job completion percentage: 49.333333
# Job completion percentage: 49.444444
# Job completion percentage: 49.555556
# Job completion percentage: 49.666667
# Job completion percentage: 49.777778
# Job completion percentage: 49.888889
# Job completion percentage: 50.000000
# Job completion percentage: 50.111111
# Job completion percentage: 50.222222
# Job completion percentage: 50.333333
# Job completion percentage: 50.444444
# Job completion percentage: 50.555556
# Job completion percentage: 50.666667
# Job completion percentage: 50.777778
# Job completion percentage: 50.888889
# Job completion percentage: 51.000000
# Job completion percentage: 51.111111
# Job completion percentage: 51.222222
# Job completion percentage: 51.333333
# Job completion percentage: 51.444444
# Job completion percentage: 51.555556
# Job completion percentage: 51.666667
# Job completion percentage: 51.777778
# Job completion percentage: 51.888889
# Job completion percentage: 52.000000
# Job completion percentage: 52.111111
# Job completion percentage: 52.222222
# Job completion percentage: 52.333333
# Job completion percentage: 52.444444
# Job completion percentage: 52.555556
# Job completion percentage: 52.666667
# Job completion percentage: 52.777778
# Job completion percentage: 52.888889
# Job completion percentage: 53.000000
# Job completion percentage: 53.111111
# Job completion percentage: 53.222222
# Job completion percentage: 53.333333
# Job completion percentage: 53.444444
# Job completion percentage: 53.555556
# Job completion percentage: 53.666667
# Job completion percentage: 53.777778
# Job completion percentage: 53.888889
# Job completion percentage: 54.000000
# Job completion percentage: 54.111111
# Job completion percentage: 54.222222
# Job completion percentage: 54.333333
# Job completion percentage: 54.444444
# Job completion percentage: 54.555556
# Job completion percentage: 54.666667
# Job completion percentage: 54.777778
# Job completion percentage: 54.888889
# Job completion percentage: 55.000000
# Job completion percentage: 55.111111
# Job completion percentage: 55.222222
# Job completion percentage: 55.333333
# Job completion percentage: 55.444444
# Job completion percentage: 55.555556
# Job completion percentage: 55.666667
# Job completion percentage: 55.777778
# Job completion percentage: 55.888889
# Job completion percentage: 56.000000
# Job completion percentage: 56.111111
# Job completion percentage: 56.222222
# Job completion percentage: 56.333333
# Job completion percentage: 56.444444
# Job completion percentage: 56.555556
# Job completion percentage: 56.666667
# Job completion percentage: 56.777778
# Job completion percentage: 56.888889
# Job completion percentage: 57.000000
# Job completion percentage: 57.111111
# Job completion percentage: 57.222222
# Job completion percentage: 57.333333
# Job completion percentage: 57.444444
# Job completion percentage: 57.555556
# Job completion percentage: 57.666667
# Job completion percentage: 57.777778
# Job completion percentage: 57.888889
# Job completion percentage: 58.000000
# Job completion percentage: 58.111111
# Job completion percentage: 58.222222
# Job completion percentage: 58.333333
# Job completion percentage: 58.444444
# Job completion percentage: 58.555556
# Job completion percentage: 58.666667
# Job completion percentage: 58.777778
# Job completion percentage: 58.888889
# Job completion percentage: 59.000000
# Job completion percentage: 59.111111
# Job completion percentage: 59.222222
# Job completion percentage: 59.333333
# Job completion percentage: 59.444444
# Job completion percentage: 59.555556
# Job completion percentage: 59.666667
# Job completion percentage: 59.777778
# Job completion percentage: 59.888889
# Job completion percentage: 60.000000
# Job completion percentage: 60.111111
# Job completion percentage: 60.222222
# Job completion percentage: 60.333333
# Job completion percentage: 60.444444
# Job completion percentage: 60.555556
# Job completion percentage: 60.666667
# Job completion percentage: 60.777778
# Job completion percentage: 60.888889
# Job completion percentage: 61.000000
# Job completion percentage: 61.111111
# Job completion percentage: 61.222222
# Job completion percentage: 61.333333
# Job completion percentage: 61.444444
# Job completion percentage: 61.555556
# Job completion percentage: 61.666667
# Job completion percentage: 61.777778
# Job completion percentage: 61.888889
# Job completion percentage: 62.000000
# Job completion percentage: 62.111111
# Job completion percentage: 62.222222
# Job completion percentage: 62.333333
# Job completion percentage: 62.444444
# Job completion percentage: 62.555556
# Job completion percentage: 62.666667
# Job completion percentage: 62.777778
# Job completion percentage: 62.888889
# Job completion percentage: 63.000000
# Job completion percentage: 63.111111
# Job completion percentage: 63.222222
# Job completion percentage: 63.333333
# Job completion percentage: 63.444444
# Job completion percentage: 63.555556
# Job completion percentage: 63.666667
# Job completion percentage: 63.777778
# Job completion percentage: 63.888889
# Job completion percentage: 64.000000
# Job completion percentage: 64.111111
# Job completion percentage: 64.222222
# Job completion percentage: 64.333333
# Job completion percentage: 64.444444
# Job completion percentage: 64.555556
# Job completion percentage: 64.666667
# Job completion percentage: 64.777778
# Job completion percentage: 64.888889
# Job completion percentage: 65.000000
# Job completion percentage: 65.111111
# Job completion percentage: 65.222222
# Job completion percentage: 65.333333
# Job completion percentage: 65.444444
# Job completion percentage: 65.555556
# Job completion percentage: 65.666667
# Job completion percentage: 65.777778
# Job completion percentage: 65.888889
# Job completion percentage: 66.000000
# Job completion percentage: 66.111111
# Job completion percentage: 66.222222
# Job completion percentage: 66.333333
# Job completion percentage: 66.444444
# Job completion percentage: 66.555556
# Job completion percentage: 66.666667
# Job completion percentage: 66.777778
# Job completion percentage: 66.888889
# Job completion percentage: 67.000000
# Job completion percentage: 67.111111
# Job completion percentage: 67.222222
# Job completion percentage: 67.333333
# Job completion percentage: 67.444444
# Job completion percentage: 67.555556
# Job completion percentage: 67.666667
# Job completion percentage: 67.777778
# Job completion percentage: 67.888889
# Job completion percentage: 68.000000
# Job completion percentage: 68.111111
# Job completion percentage: 68.222222
# Job completion percentage: 68.333333
# Job completion percentage: 68.444444
# Job completion percentage: 68.555556
# Job completion percentage: 68.666667
# Job completion percentage: 68.777778
# Job completion percentage: 68.888889
# Job completion percentage: 69.000000
# Job completion percentage: 69.111111
# Job completion percentage: 69.222222
# Job completion percentage: 69.333333
# Job completion percentage: 69.444444
# Job completion percentage: 69.555556
# Job completion percentage: 69.666667
# Job completion percentage: 69.777778
# Job completion percentage: 69.888889
# Job completion percentage: 70.000000
# Job completion percentage: 70.111111
# Job completion percentage: 70.222222
# Job completion percentage: 70.333333
# Job completion percentage: 70.444444
# Job completion percentage: 70.555556
# Job completion percentage: 70.666667
# Job completion percentage: 70.777778
# Job completion percentage: 70.888889
# Job completion percentage: 71.000000
# Job completion percentage: 71.111111
# Job completion percentage: 71.222222
# Job completion percentage: 71.333333
# Job completion percentage: 71.444444
# Job completion percentage: 71.555556
# Job completion percentage: 71.666667
# Job completion percentage: 71.777778
# Job completion percentage: 71.888889
# Job completion percentage: 72.000000
# Job completion percentage: 72.111111
# Job completion percentage: 72.222222
# Job completion percentage: 72.333333
# Job completion percentage: 72.444444
# Job completion percentage: 72.555556
# Job completion percentage: 72.666667
# Job completion percentage: 72.777778
# Job completion percentage: 72.888889
# Job completion percentage: 73.000000
# Job completion percentage: 73.111111
# Job completion percentage: 73.222222
# Job completion percentage: 73.333333
# Job completion percentage: 73.444444
# Job completion percentage: 73.555556
# Job completion percentage: 73.666667
# Job completion percentage: 73.777778
# Job completion percentage: 73.888889
# Job completion percentage: 74.000000
# Job completion percentage: 74.111111
# Job completion percentage: 74.222222
# Job completion percentage: 74.333333
# Job completion percentage: 74.444444
# Job completion percentage: 74.555556
# Job completion percentage: 74.666667
# Job completion percentage: 74.777778
# Job completion percentage: 74.888889
# Job completion percentage: 75.000000
# Job completion percentage: 75.111111
# Job completion percentage: 75.222222
# Job completion percentage: 75.333333
# Job completion percentage: 75.444444
# Job completion percentage: 75.555556
# Job completion percentage: 75.666667
# Job completion percentage: 75.777778
# Job completion percentage: 75.888889
# Job completion percentage: 76.000000
# Job completion percentage: 76.111111
# Job completion percentage: 76.222222
# Job completion percentage: 76.333333
# Job completion percentage: 76.444444
# Job completion percentage: 76.555556
# Job completion percentage: 76.666667
# Job completion percentage: 76.777778
# Job completion percentage: 76.888889
# Job completion percentage: 77.000000
# Job completion percentage: 77.111111
# Job completion percentage: 77.222222
# Job completion percentage: 77.333333
# Job completion percentage: 77.444444
# Job completion percentage: 77.555556
# Job completion percentage: 77.666667
# Job completion percentage: 77.777778
# Job completion percentage: 77.888889
# Job completion percentage: 78.000000
# Job completion percentage: 78.111111
# Job completion percentage: 78.222222
# Job completion percentage: 78.333333
# Job completion percentage: 78.444444
# Job completion percentage: 78.555556
# Job completion percentage: 78.666667
# Job completion percentage: 78.777778
# Job completion percentage: 78.888889
# Job completion percentage: 79.000000
# Job completion percentage: 79.111111
# Job completion percentage: 79.222222
# Job completion percentage: 79.333333
# Job completion percentage: 79.444444
# Job completion percentage: 79.555556
# Job completion percentage: 79.666667
# Job completion percentage: 79.777778
# Job completion percentage: 79.888889
# Job completion percentage: 80.000000
# Job completion percentage: 80.111111
# Job completion percentage: 80.222222
# Job completion percentage: 80.333333
# Job completion percentage: 80.444444
# Job completion percentage: 80.555556
# Job completion percentage: 80.666667
# Job completion percentage: 80.777778
# Job completion percentage: 80.888889
# Job completion percentage: 81.000000
# Job completion percentage: 81.111111
# Job completion percentage: 81.222222
# Job completion percentage: 81.333333
# Job completion percentage: 81.444444
# Job completion percentage: 81.555556
# Job completion percentage: 81.666667
# Job completion percentage: 81.777778
# Job completion percentage: 81.888889
# Job completion percentage: 82.000000
# Job completion percentage: 82.111111
# Job completion percentage: 82.222222
# Job completion percentage: 82.333333
# Job completion percentage: 82.444444
# Job completion percentage: 82.555556
# Job completion percentage: 82.666667
# Job completion percentage: 82.777778
# Job completion percentage: 82.888889
# Job completion percentage: 83.000000
# Job completion percentage: 83.111111
# Job completion percentage: 83.222222
# Job completion percentage: 83.333333
# Job completion percentage: 83.444444
# Job completion percentage: 83.555556
# Job completion percentage: 83.666667
# Job completion percentage: 83.777778
# Job completion percentage: 83.888889
# Job completion percentage: 84.000000
# Job completion percentage: 84.111111
# Job completion percentage: 84.222222
# Job completion percentage: 84.333333
# Job completion percentage: 84.444444
# Job completion percentage: 84.555556
# Job completion percentage: 84.666667
# Job completion percentage: 84.777778
# Job completion percentage: 84.888889
# Job completion percentage: 85.000000
# Job completion percentage: 85.111111
# Job completion percentage: 85.222222
# Job completion percentage: 85.333333
# Job completion percentage: 85.444444
# Job completion percentage: 85.555556
# Job completion percentage: 85.666667
# Job completion percentage: 85.777778
# Job completion percentage: 85.888889
# Job completion percentage: 86.000000
# Job completion percentage: 86.111111
# Job completion percentage: 86.222222
# Job completion percentage: 86.333333
# Job completion percentage: 86.444444
# Job completion percentage: 86.555556
# Job completion percentage: 86.666667
# Job completion percentage: 86.777778
# Job completion percentage: 86.888889
# Job completion percentage: 87.000000
# Job completion percentage: 87.111111
# Job completion percentage: 87.222222
# Job completion percentage: 87.333333
# Job completion percentage: 87.444444
# Job completion percentage: 87.555556
# Job completion percentage: 87.666667
# Job completion percentage: 87.777778
# Job completion percentage: 87.888889
# Job completion percentage: 88.000000
# Job completion percentage: 88.111111
# Job completion percentage: 88.222222
# Job completion percentage: 88.333333
# Job completion percentage: 88.444444
# Job completion percentage: 88.555556
# Job completion percentage: 88.666667
# Job completion percentage: 88.777778
# Job completion percentage: 88.888889
# Job completion percentage: 89.000000
# Job completion percentage: 89.111111
# Job completion percentage: 89.222222
# Job completion percentage: 89.333333
# Job completion percentage: 89.444444
# Job completion percentage: 89.555556
# Job completion percentage: 89.666667
# Job completion percentage: 89.777778
# Job completion percentage: 89.888889
# Job completion percentage: 90.000000
# Job completion percentage: 90.111111
# Job completion percentage: 90.222222
# Job completion percentage: 90.333333
# Job completion percentage: 90.444444
# Job completion percentage: 90.555556
# Job completion percentage: 90.666667
# Job completion percentage: 90.777778
# Job completion percentage: 90.888889
# Job completion percentage: 91.000000
# Job completion percentage: 91.111111
# Job completion percentage: 91.222222
# Job completion percentage: 91.333333
# Job completion percentage: 91.444444
# Job completion percentage: 91.555556
# Job completion percentage: 91.666667
# Job completion percentage: 91.777778
# Job completion percentage: 91.888889
# Job completion percentage: 92.000000
# Job completion percentage: 92.111111
# Job completion percentage: 92.222222
# Job completion percentage: 92.333333
# Job completion percentage: 92.444444
# Job completion percentage: 92.555556
# Job completion percentage: 92.666667
# Job completion percentage: 92.777778
# Job completion percentage: 92.888889
# Job completion percentage: 93.000000
# Job completion percentage: 93.111111
# Job completion percentage: 93.222222
# Job completion percentage: 93.333333
# Job completion percentage: 93.444444
# Job completion percentage: 93.555556
# Job completion percentage: 93.666667
# Job completion percentage: 93.777778
# Job completion percentage: 93.888889
# Job completion percentage: 94.000000
# Job completion percentage: 94.111111
# Job completion percentage: 94.222222
# Job completion percentage: 94.333333
# Job completion percentage: 94.444444
# Job completion percentage: 94.555556
# Job completion percentage: 94.666667
# Job completion percentage: 94.777778
# Job completion percentage: 94.888889
# Job completion percentage: 95.000000
# Job completion percentage: 95.111111
# Job completion percentage: 95.222222
# Job completion percentage: 95.333333
# Job completion percentage: 95.444444
# Job completion percentage: 95.555556
# Job completion percentage: 95.666667
# Job completion percentage: 95.777778
# Job completion percentage: 95.888889
# Job completion percentage: 96.000000
# Job completion percentage: 96.111111
# Job completion percentage: 96.222222
# Job completion percentage: 96.333333
# Job completion percentage: 96.444444
# Job completion percentage: 96.555556
# Job completion percentage: 96.666667
# Job completion percentage: 96.777778
# Job completion percentage: 96.888889
# Job completion percentage: 97.000000
# Job completion percentage: 97.111111
# Job completion percentage: 97.222222
# Job completion percentage: 97.333333
# Job completion percentage: 97.444444
# Job completion percentage: 97.555556
# Job completion percentage: 97.666667
# Job completion percentage: 97.777778
# Job completion percentage: 97.888889
# Job completion percentage: 98.000000
# Job completion percentage: 98.111111
# Job completion percentage: 98.222222
# Job completion percentage: 98.333333
# Job completion percentage: 98.444444
# Job completion percentage: 98.555556
# Job completion percentage: 98.666667
# Job completion percentage: 98.777778
# Job completion percentage: 98.888889
# Job completion percentage: 99.000000
# Job completion percentage: 99.111111
# Job completion percentage: 99.222222
# Job completion percentage: 99.333333
# Job completion percentage: 99.444444
# Job completion percentage: 99.555556
# Job completion percentage: 99.666667
# Job completion percentage: 99.777778
# Job completion percentage: 99.888889
# Job completion percentage: 100.000000
