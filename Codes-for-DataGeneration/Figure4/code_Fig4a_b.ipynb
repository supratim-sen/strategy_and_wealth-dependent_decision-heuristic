# %%
from __future__ import division
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import copy
import random

N =  50                  # Number of nodes
rw = 700                 # Wealth value of rich
pw = 300                # Wealth value of poor
we_arr = [rw, pw]       # Array storing both the wealth values
pr = 0.5                # Probability of being rich
prob_arr = [pr, 1-pr]  # Array storing probability of wealth allotment values
M = 20                  # Number of rounds
co = 50                 # Unitary Cost of co-operation
be = 100                # Unitary Benefit of co-operation
S = 50                  # Number of iterations
pl = 0.3                # Initial probability of a link being formed between any two nodes

def inv_logit(y):
    inv_logit_out =(np.exp(y)/(1+np.exp(y)))
    return inv_logit_out

def gini_calc(x):       #IN: Wealth values across the population, OUT: Gini Coefficient
    sum2=0
    for i in range(len(x)):
        sum1=0
        for j in range(len(x)):
            sum1=sum1+np.abs(x[i]-x[j])
        sum2=sum2+sum1;
    
    gini=sum2/(2*len(x)**2*np.mean(x));
    return gini

node_arr = np.arange(N)

re_ar = np.arange(0,1.1,0.1)

rc_ar = np.zeros([len(re_ar),S])   # Array for storing no of cooperations by rich individuals
rd_ar = np.zeros([len(re_ar),S])   # Array for storing no of defections by rich individuals
pd_ar = np.zeros([len(re_ar),S])   # Array for storing no of defections by poor individuals
pc_ar = np.zeros([len(re_ar),S])   # Array for storing no of cooperations by poor individuals
c_env_ar = np.zeros([len(re_ar),S])   # Array storing no of cooperative environments
d_env_ar = np.zeros([len(re_ar),S])   # Array storing no of selfish environments
eq_env_ar = np.zeros([len(re_ar),S])  # Array storing no of neutral environments
coop_ar = np.zeros([len(re_ar),S])   # Array storing no of cooperators
def_ar = np.zeros([len(re_ar),S])    # Array storing no of defectors 

flag = 0

for h1 in range(len(re_ar)):    
    for h in range(S):
        re = re_ar[h1]
        flag += 1
        rc = 0         # Flag for no of rich cooperators
        rd = 0         # Flag for no of rich defectors
        pd = 0         # Flag for no of poor defectors
        pcop = 0       # Flag for no of poor cooperators       
        c_env = 0      # Flag for no of cooperative environments
        d_env = 0      # Flag for no of defective environments
        eq_env = 0     # Flag for no of neutral environments
        f_c = 0       # Flag for no of cooperators
        f_d = 0        # Flag for no of defectors
        G = nx.erdos_renyi_graph(N, pl)
        A = nx.adjacency_matrix(G)
               
        No_of_rewiring = round((N*(N-1)/2)*re)
        Nre = int(No_of_rewiring)        
        init_wealth_array = np.random.choice(we_arr,N,p=prob_arr) 
        GINI = gini_calc(init_wealth_array)       
            
        for k in range(M):                 # Continuing the game for M rounds
            env_array = np.zeros(N)
            if (k==0):                    # First round  
                
                decision_array = np.zeros(N)
                for i in range(N):         # For all nodes in the network
                    nn = G.degree(i)
                    a = np.random.random()
                                   
                    p1 = 0.7
                    if (a <= p1):
                        decision_array[i] = 1       # Node-i decides to be cooperative                    
                        init_wealth_array[i] = init_wealth_array[i] - co*nn   # Updatation of wealth of a cooperative node
                        for l in range(N):          # Updatation of wealth of its neighbouring nodes
                            if (i==l):
                                continue
                            else:
                                if (A[i,l] == 1):
                                    init_wealth_array[l] = init_wealth_array[l] + be
                                else:
                                    continue

                    else:
                        decision_array[i] = 0          # Node-i decides to be non-cooperative
                        continue   
                               
                
            else:                     # Decision making in subsequent rounds
                new_decision_array = np.zeros(N)
                new_env_array = np.zeros(N)
                for i in range(N):         # For all nodes in the network
                                                       
                    cop = 0                     # Initializing the no of cooperator neighbours
                    for j in range(N):
                        if (A[i,j] == 1):               # If a link exists between nodes i and j
                            if (decision_array[j] == 1):        # If link j cooperated in last round
                                cop += 1
                            elif (decision_array[j] == 0):      # If link j did not cooperate in last round
                                continue
                        else:
                            continue
                
                    sum_neighbor_wealth = 0
                    for j in range(N):			# Average wealth of the neighborhors
                        if (A[i,j] == 1):
                            sum_neighbor_wealth += init_wealth_array[j]
                        else:
                            continue
                 
                    if (G.degree(i)>0):                  # For postive number of nearest neighbours
                        av_neighbor_wealth = (sum_neighbor_wealth)/G.degree(i)
                        diff_wealth = av_neighbor_wealth - (init_wealth_array[i])
                        pc = p1 + (1-p1)*(np.tanh(0.001*diff_wealth)) - 0.10 
                                               
                        cop_rat = float(cop/G.degree(i)) 
                        
                        if (cop_rat > 0.5):       # If cooperation parameter is greater than 0.5
                            
                            c = np.random.random()
                            if (c < pc):
                                new_decision_array[i] = 1       # Node-i decides to be cooperative                          
                            else:
                                new_decision_array[i] = 0

                        elif (cop_rat < 0.5):          # Cooperation parameter is lesser than 0.5
                            
                            c = np.random.random()
                            if (c < pc):                        
                                new_decision_array[i] = 0
                            else:
                                new_decision_array[i] = 1
                            
                        elif (cop_rat == 0.5):       # Neutral environment
                              #new_env_array[i] = 2
                              c = np.random.random()
                              if (c<=pc):
                                  new_decision_array[i] = 1
                              else:
                                  new_decision_array[i] = 0
                                    
                        if (new_decision_array[i]==1):
                            if (diff_wealth<0):
                                rc += 1
                            else:
                                pcop += 1
                        elif (new_decision_array[i]==0): 
                            if (diff_wealth>0):
                                pd += 1
                            else:
                                rd += 1
                                
                    else:
                        new_decision_array[i] = 0                 
                
                # Wealth update
                for i in range(N):
                    if (new_decision_array[i] == 1): 
                        init_wealth_array[i] = init_wealth_array[i] - co*(G.degree(i))   # Updatation of wealth of a cooperative node
                        for l in range(N):          	# Updatation of wealth of its neighbouring nodes
                            if (i==l):
                                continue
                            else:
                                if (A[i,l] == 1):
                                    init_wealth_array[l] = init_wealth_array[l] + be
                                else:
                                    continue
                    else:
                        continue       
                               
                
                
                decision_array = copy.copy(new_decision_array)        
                    
            # Rewiring step
                   
            temp_array = []                                                
            
            
            while (len(temp_array) < Nre) :            
                i = random.choice(node_arr)
                j = random.choice(node_arr)
                    
                if (i==j):
                    continue
                else:
                
                    if (i,j) in temp_array:
                        continue
                    elif (j,i) in temp_array:
                        continue
                    else:
                        temp_array.append((i,j))
                        temp = [i,j]
                                                             
                        if (A[i,j] == 1):                              # If a link exists between the selected pair
                            b = random.choice(temp)
                            
                            if (b == i):                               # If node-i is given the choice to break or not
                                if (decision_array[j] == 0):
                                    c = np.random.random()
                                    if (c < 0.7):
                                        G.remove_edge(i,j)                 # Breakage of link for node-i disagreeing
                                  
                                    else:
                                        continue                        # Link is kept intact
                                else:
                                    c = np.random.random()
                                    if (c < 0.87):
                                        continue
                                    else:
                                        G.remove_edge(i,j)
                            else:                                   # If node-j is given the choice to break or not	
                                if (decision_array[i] == 0):
                                    c = np.random.random()
                                    if (c < 0.7):                                    
                                        G.remove_edge(i,j)         # Breakage of link for node-j disagreeing
                                    else:
                                        continue			# Link is kept intact
                                else:
                                    c = np.random.random()
                                    if (c < 0.87):
                                        continue
                                    else:
                                        G.remove_edge(i,j)
                                                                
            
                        else:                 # If a link does not exist between the selected pair
                            if (decision_array[i] == 1 and decision_array[j] == 1):
                                c = np.random.random()
                                if (c < 0.93):
                                    G.add_edge(i,j)
                                else:
                                    continue
                            
                            if (decision_array[i] == 0 and decision_array[j] == 0):
                                c = np.random.random()
                                if (c < 0.80):
                                    continue
                                else:
                                    G.add_edge(i,j)
                        
                            if (decision_array[i] == 0 and decision_array[j] == 1):
                                c = np.random.random()
                                if (c < 0.70):
                                    continue
                                else:
                                    G.add_edge(i,j)
                                
                            if (decision_array[i] == 1 and decision_array[j] == 0):
                                c = np.random.random()
                                if (c < 0.70):
                                    continue
                                else:
                                    G.add_edge(i,j)
                                
            A = nx.adjacency_matrix(G)       # Adjacency matrix of the network  
            for i in range(N):         # For all nodes in the network                                                   
                    cop = 0                     # Initializing the no of cooperator neighbours
                    for j in range(N):
                        if (A[i,j] == 1):               # If a link exists between nodes i and j
                            if (decision_array[j] == 1):        # If link j cooperated in last round
                                cop += 1
                            elif (decision_array[j] == 0):      # If link j did not cooperate in last round
                                continue
                        else:
                            continue
                    if (G.degree(i)>0):
                        cop_rat = float(cop/G.degree(i))                    
                        if (cop_rat > 0.5):       # If cooperation parameter is greater than 0.5
                            env_array[i] = 1
                        elif (cop_rat == 0.5):
                            env_array[i] = 2
                        elif(cop_rat < 0.5):
                            env_array[i] = 0
                    else:
                        env_array[i] = 0
                        
            c_env += np.count_nonzero(env_array == 1)
            d_env += np.count_nonzero(env_array == 0)
            eq_env += np.count_nonzero(env_array == 2)
            
        rc_ar[h1,h] = rc 
        pd_ar[h1,h] = pd 
        rd_ar[h1,h] = rd 
        pc_ar[h1,h] = pcop 
        c_env_ar[h1,h] = c_env
        d_env_ar[h1,h] = d_env
        eq_env_ar[h1,h] = eq_env
        coop_ar[h1,h] = rc_ar[h1,h] + pc_ar[h1,h]
        def_ar[h1,h] = pd_ar[h1,h] + rd_ar[h1,h]
        
        yo = (flag*100)/(len(re_ar)*S)
        print('Job completion percentage: %f' %yo)
        
np.savez('strat_wealth_vs_re', rc_ar=rc_ar, pd_ar=pd_ar, rd_ar=rd_ar, pc_ar=pc_ar, c_env_ar=c_env_ar, d_env_ar=d_env_ar, eq_env_ar=eq_env_ar, coop_ar=coop_ar, def_ar=def_ar)
# Out:
# Job completion percentage: 0.181818
# Job completion percentage: 0.363636
# Job completion percentage: 0.545455
# Job completion percentage: 0.727273
# Job completion percentage: 0.909091
# Job completion percentage: 1.090909
# Job completion percentage: 1.272727
# Job completion percentage: 1.454545
# Job completion percentage: 1.636364
# Job completion percentage: 1.818182
# Job completion percentage: 2.000000
# Job completion percentage: 2.181818
# Job completion percentage: 2.363636
# Job completion percentage: 2.545455
# Job completion percentage: 2.727273
# Job completion percentage: 2.909091
# Job completion percentage: 3.090909
# Job completion percentage: 3.272727
# Job completion percentage: 3.454545
# Job completion percentage: 3.636364
# Job completion percentage: 3.818182
# Job completion percentage: 4.000000
# Job completion percentage: 4.181818
# Job completion percentage: 4.363636
# Job completion percentage: 4.545455
# Job completion percentage: 4.727273
# Job completion percentage: 4.909091
# Job completion percentage: 5.090909
# Job completion percentage: 5.272727
# Job completion percentage: 5.454545
# Job completion percentage: 5.636364
# Job completion percentage: 5.818182
# Job completion percentage: 6.000000
# Job completion percentage: 6.181818
# Job completion percentage: 6.363636
# Job completion percentage: 6.545455
# Job completion percentage: 6.727273
# Job completion percentage: 6.909091
# Job completion percentage: 7.090909
# Job completion percentage: 7.272727
# Job completion percentage: 7.454545
# Job completion percentage: 7.636364
# Job completion percentage: 7.818182
# Job completion percentage: 8.000000
# Job completion percentage: 8.181818
# Job completion percentage: 8.363636
# Job completion percentage: 8.545455
# Job completion percentage: 8.727273
# Job completion percentage: 8.909091
# Job completion percentage: 9.090909
# Job completion percentage: 9.272727
# Job completion percentage: 9.454545
# Job completion percentage: 9.636364
# Job completion percentage: 9.818182
# Job completion percentage: 10.000000
# Job completion percentage: 10.181818
# Job completion percentage: 10.363636
# Job completion percentage: 10.545455
# Job completion percentage: 10.727273
# Job completion percentage: 10.909091
# Job completion percentage: 11.090909
# Job completion percentage: 11.272727
# Job completion percentage: 11.454545
# Job completion percentage: 11.636364
# Job completion percentage: 11.818182
# Job completion percentage: 12.000000
# Job completion percentage: 12.181818
# Job completion percentage: 12.363636
# Job completion percentage: 12.545455
# Job completion percentage: 12.727273
# Job completion percentage: 12.909091
# Job completion percentage: 13.090909
# Job completion percentage: 13.272727
# Job completion percentage: 13.454545
# Job completion percentage: 13.636364
# Job completion percentage: 13.818182
# Job completion percentage: 14.000000
# Job completion percentage: 14.181818
# Job completion percentage: 14.363636
# Job completion percentage: 14.545455
# Job completion percentage: 14.727273
# Job completion percentage: 14.909091
# Job completion percentage: 15.090909
# Job completion percentage: 15.272727
# Job completion percentage: 15.454545
# Job completion percentage: 15.636364
# Job completion percentage: 15.818182
# Job completion percentage: 16.000000
# Job completion percentage: 16.181818
# Job completion percentage: 16.363636
# Job completion percentage: 16.545455
# Job completion percentage: 16.727273
# Job completion percentage: 16.909091
# Job completion percentage: 17.090909
# Job completion percentage: 17.272727
# Job completion percentage: 17.454545
# Job completion percentage: 17.636364
# Job completion percentage: 17.818182
# Job completion percentage: 18.000000
# Job completion percentage: 18.181818
# Job completion percentage: 18.363636
# Job completion percentage: 18.545455
# Job completion percentage: 18.727273
# Job completion percentage: 18.909091
# Job completion percentage: 19.090909
# Job completion percentage: 19.272727
# Job completion percentage: 19.454545
# Job completion percentage: 19.636364
# Job completion percentage: 19.818182
# Job completion percentage: 20.000000
# Job completion percentage: 20.181818
# Job completion percentage: 20.363636
# Job completion percentage: 20.545455
# Job completion percentage: 20.727273
# Job completion percentage: 20.909091
# Job completion percentage: 21.090909
# Job completion percentage: 21.272727
# Job completion percentage: 21.454545
# Job completion percentage: 21.636364
# Job completion percentage: 21.818182
# Job completion percentage: 22.000000
# Job completion percentage: 22.181818
# Job completion percentage: 22.363636
# Job completion percentage: 22.545455
# Job completion percentage: 22.727273
# Job completion percentage: 22.909091
# Job completion percentage: 23.090909
# Job completion percentage: 23.272727
# Job completion percentage: 23.454545
# Job completion percentage: 23.636364
# Job completion percentage: 23.818182
# Job completion percentage: 24.000000
# Job completion percentage: 24.181818
# Job completion percentage: 24.363636
# Job completion percentage: 24.545455
# Job completion percentage: 24.727273
# Job completion percentage: 24.909091
# Job completion percentage: 25.090909
# Job completion percentage: 25.272727
# Job completion percentage: 25.454545
# Job completion percentage: 25.636364
# Job completion percentage: 25.818182
# Job completion percentage: 26.000000
# Job completion percentage: 26.181818
# Job completion percentage: 26.363636
# Job completion percentage: 26.545455
# Job completion percentage: 26.727273
# Job completion percentage: 26.909091
# Job completion percentage: 27.090909
# Job completion percentage: 27.272727
# Job completion percentage: 27.454545
# Job completion percentage: 27.636364
# Job completion percentage: 27.818182
# Job completion percentage: 28.000000
# Job completion percentage: 28.181818
# Job completion percentage: 28.363636
# Job completion percentage: 28.545455
# Job completion percentage: 28.727273
# Job completion percentage: 28.909091
# Job completion percentage: 29.090909
# Job completion percentage: 29.272727
# Job completion percentage: 29.454545
# Job completion percentage: 29.636364
# Job completion percentage: 29.818182
# Job completion percentage: 30.000000
# Job completion percentage: 30.181818
# Job completion percentage: 30.363636
# Job completion percentage: 30.545455
# Job completion percentage: 30.727273
# Job completion percentage: 30.909091
# Job completion percentage: 31.090909
# Job completion percentage: 31.272727
# Job completion percentage: 31.454545
# Job completion percentage: 31.636364
# Job completion percentage: 31.818182
# Job completion percentage: 32.000000
# Job completion percentage: 32.181818
# Job completion percentage: 32.363636
# Job completion percentage: 32.545455
# Job completion percentage: 32.727273
# Job completion percentage: 32.909091
# Job completion percentage: 33.090909
# Job completion percentage: 33.272727
# Job completion percentage: 33.454545
# Job completion percentage: 33.636364
# Job completion percentage: 33.818182
# Job completion percentage: 34.000000
# Job completion percentage: 34.181818
# Job completion percentage: 34.363636
# Job completion percentage: 34.545455
# Job completion percentage: 34.727273
# Job completion percentage: 34.909091
# Job completion percentage: 35.090909
# Job completion percentage: 35.272727
# Job completion percentage: 35.454545
# Job completion percentage: 35.636364
# Job completion percentage: 35.818182
# Job completion percentage: 36.000000
# Job completion percentage: 36.181818
# Job completion percentage: 36.363636
# Job completion percentage: 36.545455
# Job completion percentage: 36.727273
# Job completion percentage: 36.909091
# Job completion percentage: 37.090909
# Job completion percentage: 37.272727
# Job completion percentage: 37.454545
# Job completion percentage: 37.636364
# Job completion percentage: 37.818182
# Job completion percentage: 38.000000
# Job completion percentage: 38.181818
# Job completion percentage: 38.363636
# Job completion percentage: 38.545455
# Job completion percentage: 38.727273
# Job completion percentage: 38.909091
# Job completion percentage: 39.090909
# Job completion percentage: 39.272727
# Job completion percentage: 39.454545
# Job completion percentage: 39.636364
# Job completion percentage: 39.818182
# Job completion percentage: 40.000000
# Job completion percentage: 40.181818
# Job completion percentage: 40.363636
# Job completion percentage: 40.545455
# Job completion percentage: 40.727273
# Job completion percentage: 40.909091
# Job completion percentage: 41.090909
# Job completion percentage: 41.272727
# Job completion percentage: 41.454545
# Job completion percentage: 41.636364
# Job completion percentage: 41.818182
# Job completion percentage: 42.000000
# Job completion percentage: 42.181818
# Job completion percentage: 42.363636
# Job completion percentage: 42.545455
# Job completion percentage: 42.727273
# Job completion percentage: 42.909091
# Job completion percentage: 43.090909
# Job completion percentage: 43.272727
# Job completion percentage: 43.454545
# Job completion percentage: 43.636364
# Job completion percentage: 43.818182
# Job completion percentage: 44.000000
# Job completion percentage: 44.181818
# Job completion percentage: 44.363636
# Job completion percentage: 44.545455
# Job completion percentage: 44.727273
# Job completion percentage: 44.909091
# Job completion percentage: 45.090909
# Job completion percentage: 45.272727
# Job completion percentage: 45.454545
# Job completion percentage: 45.636364
# Job completion percentage: 45.818182
# Job completion percentage: 46.000000
# Job completion percentage: 46.181818
# Job completion percentage: 46.363636
# Job completion percentage: 46.545455
# Job completion percentage: 46.727273
# Job completion percentage: 46.909091
# Job completion percentage: 47.090909
# Job completion percentage: 47.272727
# Job completion percentage: 47.454545
# Job completion percentage: 47.636364
# Job completion percentage: 47.818182
# Job completion percentage: 48.000000
# Job completion percentage: 48.181818
# Job completion percentage: 48.363636
# Job completion percentage: 48.545455
# Job completion percentage: 48.727273
# Job completion percentage: 48.909091
# Job completion percentage: 49.090909
# Job completion percentage: 49.272727
# Job completion percentage: 49.454545
# Job completion percentage: 49.636364
# Job completion percentage: 49.818182
# Job completion percentage: 50.000000
# Job completion percentage: 50.181818
# Job completion percentage: 50.363636
# Job completion percentage: 50.545455
# Job completion percentage: 50.727273
# Job completion percentage: 50.909091
# Job completion percentage: 51.090909
# Job completion percentage: 51.272727
# Job completion percentage: 51.454545
# Job completion percentage: 51.636364
# Job completion percentage: 51.818182
# Job completion percentage: 52.000000
# Job completion percentage: 52.181818
# Job completion percentage: 52.363636
# Job completion percentage: 52.545455
# Job completion percentage: 52.727273
# Job completion percentage: 52.909091
# Job completion percentage: 53.090909
# Job completion percentage: 53.272727
# Job completion percentage: 53.454545
# Job completion percentage: 53.636364
# Job completion percentage: 53.818182
# Job completion percentage: 54.000000
# Job completion percentage: 54.181818
# Job completion percentage: 54.363636
# Job completion percentage: 54.545455
# Job completion percentage: 54.727273
# Job completion percentage: 54.909091
# Job completion percentage: 55.090909
# Job completion percentage: 55.272727
# Job completion percentage: 55.454545
# Job completion percentage: 55.636364
# Job completion percentage: 55.818182
# Job completion percentage: 56.000000
# Job completion percentage: 56.181818
# Job completion percentage: 56.363636
# Job completion percentage: 56.545455
# Job completion percentage: 56.727273
# Job completion percentage: 56.909091
# Job completion percentage: 57.090909
# Job completion percentage: 57.272727
# Job completion percentage: 57.454545
# Job completion percentage: 57.636364
# Job completion percentage: 57.818182
# Job completion percentage: 58.000000
# Job completion percentage: 58.181818
# Job completion percentage: 58.363636
# Job completion percentage: 58.545455
# Job completion percentage: 58.727273
# Job completion percentage: 58.909091
# Job completion percentage: 59.090909
# Job completion percentage: 59.272727
# Job completion percentage: 59.454545
# Job completion percentage: 59.636364
# Job completion percentage: 59.818182
# Job completion percentage: 60.000000
# Job completion percentage: 60.181818
# Job completion percentage: 60.363636
# Job completion percentage: 60.545455
# Job completion percentage: 60.727273
# Job completion percentage: 60.909091
# Job completion percentage: 61.090909
# Job completion percentage: 61.272727
# Job completion percentage: 61.454545
# Job completion percentage: 61.636364
# Job completion percentage: 61.818182
# Job completion percentage: 62.000000
# Job completion percentage: 62.181818
# Job completion percentage: 62.363636
# Job completion percentage: 62.545455
# Job completion percentage: 62.727273
# Job completion percentage: 62.909091
# Job completion percentage: 63.090909
# Job completion percentage: 63.272727
# Job completion percentage: 63.454545
# Job completion percentage: 63.636364
# Job completion percentage: 63.818182
# Job completion percentage: 64.000000
# Job completion percentage: 64.181818
# Job completion percentage: 64.363636
# Job completion percentage: 64.545455
# Job completion percentage: 64.727273
# Job completion percentage: 64.909091
# Job completion percentage: 65.090909
# Job completion percentage: 65.272727
# Job completion percentage: 65.454545
# Job completion percentage: 65.636364
# Job completion percentage: 65.818182
# Job completion percentage: 66.000000
# Job completion percentage: 66.181818
# Job completion percentage: 66.363636
# Job completion percentage: 66.545455
# Job completion percentage: 66.727273
# Job completion percentage: 66.909091
# Job completion percentage: 67.090909
# Job completion percentage: 67.272727
# Job completion percentage: 67.454545
# Job completion percentage: 67.636364
# Job completion percentage: 67.818182
# Job completion percentage: 68.000000
# Job completion percentage: 68.181818
# Job completion percentage: 68.363636
# Job completion percentage: 68.545455
# Job completion percentage: 68.727273
# Job completion percentage: 68.909091
# Job completion percentage: 69.090909
# Job completion percentage: 69.272727
# Job completion percentage: 69.454545
# Job completion percentage: 69.636364
# Job completion percentage: 69.818182
# Job completion percentage: 70.000000
# Job completion percentage: 70.181818
# Job completion percentage: 70.363636
# Job completion percentage: 70.545455
# Job completion percentage: 70.727273
# Job completion percentage: 70.909091
# Job completion percentage: 71.090909
# Job completion percentage: 71.272727
# Job completion percentage: 71.454545
# Job completion percentage: 71.636364
# Job completion percentage: 71.818182
# Job completion percentage: 72.000000
# Job completion percentage: 72.181818
# Job completion percentage: 72.363636
# Job completion percentage: 72.545455
# Job completion percentage: 72.727273
# Job completion percentage: 72.909091
# Job completion percentage: 73.090909
# Job completion percentage: 73.272727
# Job completion percentage: 73.454545
# Job completion percentage: 73.636364
# Job completion percentage: 73.818182
# Job completion percentage: 74.000000
# Job completion percentage: 74.181818
# Job completion percentage: 74.363636
# Job completion percentage: 74.545455
# Job completion percentage: 74.727273
# Job completion percentage: 74.909091
# Job completion percentage: 75.090909
# Job completion percentage: 75.272727
# Job completion percentage: 75.454545
# Job completion percentage: 75.636364
# Job completion percentage: 75.818182
# Job completion percentage: 76.000000
# Job completion percentage: 76.181818
# Job completion percentage: 76.363636
# Job completion percentage: 76.545455
# Job completion percentage: 76.727273
# Job completion percentage: 76.909091
# Job completion percentage: 77.090909
# Job completion percentage: 77.272727
# Job completion percentage: 77.454545
# Job completion percentage: 77.636364
# Job completion percentage: 77.818182
# Job completion percentage: 78.000000
# Job completion percentage: 78.181818
# Job completion percentage: 78.363636
# Job completion percentage: 78.545455
# Job completion percentage: 78.727273
# Job completion percentage: 78.909091
# Job completion percentage: 79.090909
# Job completion percentage: 79.272727
# Job completion percentage: 79.454545
# Job completion percentage: 79.636364
# Job completion percentage: 79.818182
# Job completion percentage: 80.000000
# Job completion percentage: 80.181818
# Job completion percentage: 80.363636
# Job completion percentage: 80.545455
# Job completion percentage: 80.727273
# Job completion percentage: 80.909091
# Job completion percentage: 81.090909
# Job completion percentage: 81.272727
# Job completion percentage: 81.454545
# Job completion percentage: 81.636364
# Job completion percentage: 81.818182
# Job completion percentage: 82.000000
# Job completion percentage: 82.181818
# Job completion percentage: 82.363636
# Job completion percentage: 82.545455
# Job completion percentage: 82.727273
# Job completion percentage: 82.909091
# Job completion percentage: 83.090909
# Job completion percentage: 83.272727
# Job completion percentage: 83.454545
# Job completion percentage: 83.636364
# Job completion percentage: 83.818182
# Job completion percentage: 84.000000
# Job completion percentage: 84.181818
# Job completion percentage: 84.363636
# Job completion percentage: 84.545455
# Job completion percentage: 84.727273
# Job completion percentage: 84.909091
# Job completion percentage: 85.090909
# Job completion percentage: 85.272727
# Job completion percentage: 85.454545
# Job completion percentage: 85.636364
# Job completion percentage: 85.818182
# Job completion percentage: 86.000000
# Job completion percentage: 86.181818
# Job completion percentage: 86.363636
# Job completion percentage: 86.545455
# Job completion percentage: 86.727273
# Job completion percentage: 86.909091
# Job completion percentage: 87.090909
# Job completion percentage: 87.272727
# Job completion percentage: 87.454545
# Job completion percentage: 87.636364
# Job completion percentage: 87.818182
# Job completion percentage: 88.000000
# Job completion percentage: 88.181818
# Job completion percentage: 88.363636
# Job completion percentage: 88.545455
# Job completion percentage: 88.727273
# Job completion percentage: 88.909091
# Job completion percentage: 89.090909
# Job completion percentage: 89.272727
# Job completion percentage: 89.454545
# Job completion percentage: 89.636364
# Job completion percentage: 89.818182
# Job completion percentage: 90.000000
# Job completion percentage: 90.181818
# Job completion percentage: 90.363636
# Job completion percentage: 90.545455
# Job completion percentage: 90.727273
# Job completion percentage: 90.909091
# Job completion percentage: 91.090909
# Job completion percentage: 91.272727
# Job completion percentage: 91.454545
# Job completion percentage: 91.636364
# Job completion percentage: 91.818182
# Job completion percentage: 92.000000
# Job completion percentage: 92.181818
# Job completion percentage: 92.363636
# Job completion percentage: 92.545455
# Job completion percentage: 92.727273
# Job completion percentage: 92.909091
# Job completion percentage: 93.090909
# Job completion percentage: 93.272727
# Job completion percentage: 93.454545
# Job completion percentage: 93.636364
# Job completion percentage: 93.818182
# Job completion percentage: 94.000000
# Job completion percentage: 94.181818
# Job completion percentage: 94.363636
# Job completion percentage: 94.545455
# Job completion percentage: 94.727273
# Job completion percentage: 94.909091
# Job completion percentage: 95.090909
# Job completion percentage: 95.272727
# Job completion percentage: 95.454545
# Job completion percentage: 95.636364
# Job completion percentage: 95.818182
# Job completion percentage: 96.000000
# Job completion percentage: 96.181818
# Job completion percentage: 96.363636
# Job completion percentage: 96.545455
# Job completion percentage: 96.727273
# Job completion percentage: 96.909091
# Job completion percentage: 97.090909
# Job completion percentage: 97.272727
# Job completion percentage: 97.454545
# Job completion percentage: 97.636364
# Job completion percentage: 97.818182
# Job completion percentage: 98.000000
# Job completion percentage: 98.181818
# Job completion percentage: 98.363636
# Job completion percentage: 98.545455
# Job completion percentage: 98.727273
# Job completion percentage: 98.909091
# Job completion percentage: 99.090909
# Job completion percentage: 99.272727
# Job completion percentage: 99.454545
# Job completion percentage: 99.636364
# Job completion percentage: 99.818182
# Job completion percentage: 100.000000
